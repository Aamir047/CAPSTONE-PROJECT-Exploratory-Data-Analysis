# %% [markdown]
# <a href="https://colab.research.google.com/github/Aamir047/CAPSTONE-PROJECT-Exploratory-Data-Analysis/blob/main/AirBnb_Bookings_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -
# AirBnb Bookings Analysis

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**
# The Airbnb NYC 2019 dataset consists of 48,895 records and 16 features detailing listings across New York City. The dataset provides insights into various aspects of Airbnb rentals, such as host details, geographical information, listing features, pricing, and guest engagement metrics. The goal of this exploratory data analysis (EDA) is to uncover patterns, trends, and anomalies within the dataset to better understand the dynamics of the Airbnb market in NYC.

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The Airbnb NYC 2019 dataset offers an opportunity to explore the dynamics of short-term rentals in one of the world’s most prominent metropolitan areas. However, understanding the distribution, pricing trends, host behavior, and customer engagement requires in-depth analysis. The key challenges include identifying factors that influence pricing, determining areas with high demand, and uncovering patterns in availability and customer reviews.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this project is to analyze and uncover insights from the Airbnb NYC 2019 dataset to better understand the dynamics of the short-term rental market in New York City. The analysis aims to provide actionable intelligence to various stakeholders.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# Import Libraries
# Data manipulation and analysis
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistics and computations
from scipy.stats import zscore

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
drive_path = '/Airbnb NYC 2019.csv'
df = pd.read_csv(drive_path)
print(df.head)
# Out:
# <bound method NDFrame.head of              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
rows, columns = df.shape

print(f"The dataset contains {rows} rows and {columns} columns.")
# Out:
# The dataset contains 48895 rows and 16 columns.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print("Dataset Information:")
print(df.info())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
#Find the number of duplicate rows in the dataset :
duplicates = df.duplicated().sum()

print(f"Number of duplicate rows in the dataset: {duplicates}")

# To remove duplicates we can use the below code snipet:
#Removes duplicate rows if you decide to clean the data
df_cleaned = df.drop_duplicates()

# shape after removing duplicates
rows_cleaned, columns_cleaned = df_cleaned.shape
print(f"After removing duplicates, the dataset contains {rows_cleaned} rows and {columns_cleaned} columns.")
# Out:
# Number of duplicate rows in the dataset: 0
# After removing duplicates, the dataset contains 48895 rows and 16 columns.

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values = df.isnull().sum()

print("Missing Values in Each Column:")
print(missing_values)
# Out:
# Missing Values in Each Column:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
import seaborn as sns
import matplotlib.pyplot as plt

# Define dist_col_list as a list of numeric columns (replace with relevant columns in your dataset)
dist_col_list = ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'availability_365']

# Plotting the heatmap for correlation
plt.figure(figsize=(10, 6))
heatmap = sns.heatmap(df[dist_col_list].corr(), linewidths=0, vmin=-1, annot=True, cmap="YlGnBu")
plt.title('Correlation Heatmap of Selected Numerical Columns')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The Airbnb NYC 2019 dataset contains 48,895 listings with 16 columns. It includes details like host information, room types, prices, reviews, availability, and geographical data. The dataset has both numerical (e.g., price, reviews) and categorical (e.g., room type, neighborhood) columns. Some columns have missing values, particularly in reviews data. It provides insights into pricing trends, host behavior, and customer engagement across different neighborhoods in New York City.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
columns = df.columns.tolist()

# Display the column names
print("Dataset Columns:")
print(columns)
# Out:
# Dataset Columns:
# ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# %%
# Dataset Describe
summary = df.describe()

# Display the summary statistics
print("Dataset Summary Statistics:")
print(summary)
# Out:
# Dataset Summary Statistics:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# host_id: Unique identifier for the host.
# host_name: Name of the host.
# neighbourhood_group: Borough where the listing is located (e.g., Manhattan, Brooklyn).
# neighbourhood: Specific neighborhood within the borough.
# latitude: Latitude of the listing.
# longitude: Longitude of the listing.
# room_type: Type of room (e.g., Entire home/apt, Private room).
# price: Price per night for the listing.
# minimum_nights: Minimum number of nights required for booking.
# number_of_reviews: Total number of reviews for the listing.
# reviews_per_month: Average number of reviews per month.
# availability_365: Number of days the listing is available in a year.
# last_review: Date of the most recent review.
# calculated_host_listings_count: Number of listings managed by the host.
# These columns capture key details about the listings, their pricing, availability, and reviews.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
unique_values = df.nunique() #This function returns the count of unique values in each column

# Displays unique values count for each column
print("Unique Values for Each Column:")
print(unique_values)
# Out:
# Unique Values for Each Column:
# id                                48895
# name                              47896
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Step 1: I have loaded the dataset
df = pd.read_csv('/Airbnb NYC 2019.csv')

# Step 2: Checked and removed the duplicate rows
df = df.drop_duplicates()

# Step 3: Handled the missing values
# For numerical columns, filled in the missing values with the median
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
df[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].median())

# For categorical columns, I have filled in the missing values with the mode
categorical_columns = df.select_dtypes(include=['object']).columns
df[categorical_columns] = df[categorical_columns].fillna(df[categorical_columns].mode().iloc[0])

# Step 4: I have converted the columns to appropriate data types
# Converted 'last_review' to datetime format
df['last_review'] = pd.to_datetime(df['last_review'], errors='coerce')

# Step 5: Removed unnecessary columns
# Example: Dropping a column like 'host_name' that may not be essential for analysis
df = df.drop(columns=['host_name'])

# Step 6: I have reset the index after cleaning
df.reset_index(drop=True, inplace=True)

# Step 7: Checked the dataset info after cleaning
print(df.info())

# Optional: Checked for unique values in each column
unique_values = df.nunique()
print("Unique Values for Each Column:")
print(unique_values)

# Step 8: Quick summary statistics
print("Dataset Summary Statistics:")
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48895 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   neighbourhood_group             48895 non-null  object
#  4   neighbourhood                   48895 non-null  object
#  5   latitude                        48895 non-null  float64
#  6   longitude                       48895 non-null  float64
#  7   room_type                       48895 non-null  object
#  8   price                           48895 non-null  int64
#  9   minimum_nights                  48895 non-null  int64
#  10  number_of_reviews               48895 non-null  int64
#  11  last_review                     48895 non-null  datetime64[ns]
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Removed Duplicates: Eliminated any repeated rows.
# Handled Missing Values: Filled missing numerical values with the median and categorical values with the mode.
# Converted Data Types: Changed last_review to a datetime format.
# Dropped Unnecessary Columns: Removed columns like host_name.
# Reset Index: Cleaned the dataset index.
# Insights:
# The dataset is now free from duplicates and missing values.
# last_review is now in the correct format for time analysis.
# The data is ready for analysis on pricing, reviews, and availability trends.**

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(10, 6))

# Created a boxplot to visualize the distribution of prices across room types
sns.boxplot(x='room_type', y='price', data=df)

# Added a title and labels
plt.title('Price Distribution Across Different Room Types', fontsize=16)
plt.xlabel('Room Type', fontsize=12)
plt.ylabel('Price (USD)', fontsize=12)

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a boxplot to visualize the distribution of prices across different room types because it effectively highlights the central tendency (median), spread (quartiles), and outliers of the data. This allows for a clear comparison of how prices vary between room types, helping identify trends and price differences, such as whether certain room types have higher or more variable prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The boxplot reveals that Entire home/apt listings have significantly higher prices compared to Private rooms and Shared rooms, with a wider range of prices and more outliers. Private rooms tend to have a more consistent price range, while Shared rooms are generally the least expensive, with a lower median price and fewer outliers. This indicates that room type is a major factor influencing pricing on Airbnb.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the boxplot can indeed create a positive business impact by guiding strategic pricing and marketing decisions. For example, understanding that Entire home/apt listings command higher prices can inform hosts and property managers to better tailor their offerings and pricing strategies for premium listings. Similarly, knowing that Private rooms have more consistent pricing allows for targeted promotions or adjustments in less expensive segments.
# However, there could be a potential negative impact if Shared rooms are overly priced or not differentiated enough from private rooms, leading to lower occupancy rates. Additionally, the higher price spread for Entire home/apt listings may indicate a market with extreme variations, potentially leading to customer dissatisfaction or reduced demand if pricing isn't properly aligned with value.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(10, 6))

# Created a scatter plot to visualize the relationship between price and number of reviews
sns.scatterplot(x='number_of_reviews', y='price', data=df, alpha=0.6)

# Added a title and labels
plt.title('Price vs Number of Reviews', fontsize=16)
plt.xlabel('Number of Reviews', fontsize=12)
plt.ylabel('Price (USD)', fontsize=12)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a scatter plot to visualize the relationship between price and number of reviews because it allows for a clear view of any potential correlation between these two variables. By plotting each listing as a point, we can easily identify trends, clusters, or outliers, helping to determine if higher-priced listings tend to have more reviews or if there are other patterns in customer engagement relative to pricing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot reveals that there is no strong correlation between price and number of reviews, as the data points are widely dispersed. Some high-priced listings have few reviews, while others have many, indicating that pricing does not necessarily drive the volume of reviews. This suggests that factors other than price, such as location, listing quality, or guest experience, may play a more significant role in generating reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight that price does not strongly correlate with the number of reviews can help businesses focus on improving other factors, such as enhancing guest experience, location appeal, and listing quality, to boost reviews. This could lead to a positive business impact by emphasizing the importance of guest satisfaction and marketing efforts, rather than just pricing strategies, to increase bookings and customer engagement.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(12, 6))

plt.figure(figsize=(12, 6))

# Created a bar plot to visualize the average availability across neighborhood groups
sns.barplot(x='neighbourhood_group', y='availability_365', data=df, palette="Set2")

# Added a title and labels
plt.title('Average Availability Across Neighborhood Groups', fontsize=16)
plt.xlabel('Neighborhood Group', fontsize=12)
plt.ylabel('Average Availability (Days per Year)', fontsize=12)

plt.show()
# Out:
# <ipython-input-67-0698594a1f4b>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='neighbourhood_group', y='availability_365', data=df, palette="Set2")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar Plot: This chart shows the average availability of listings in each neighborhood group. It helps compare the availability of properties across different boroughs (like Manhattan, Brooklyn, etc.).This visualization provides clear insights into which neighborhoods have more available listings, helping to identify areas with higher or lower property availability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar plot reveals that neighborhoods like Staten Island tend to have higher average availability, suggesting that listings in these areas are available for more days throughout the year. In contrast, neighborhoods like Brooklyn  and Manhattan show lower average availability, indicating that properties in these areas may be rented out less frequently or have more seasonal availability. This insight can help businesses optimize pricing and availability strategies based on neighborhood trends.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights from the bar plot can indeed create a positive business impact. For instance, Staten Island's higher average availability suggests that hosts in this area can optimize their pricing by offering flexible booking options to attract more guests, potentially increasing bookings. Meanwhile, Manhattan's lower availability could indicate high demand, allowing hosts to price listings higher due to limited availability, leading to more competitive pricing strategies.
#
# However, insights that Staten Island listings might have lower demand compared to more popular neighborhoods could lead to negative growth if businesses do not address this gap. If hosts in Staten Island are unable to attract guests at competitive prices, their properties may remain under-booked, limiting revenue. Similarly, if Manhattan's high demand results in inflated prices without aligning with guest expectations, it could lead to customer dissatisfaction and fewer bookings. Therefore, a balanced approach to pricing and availability tailored to each neighborhood is critical for sustained growth.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(14, 7))

# Created a strip plot to visualize the distribution of prices across neighborhoods
sns.stripplot(x='neighbourhood_group', y='price', data=df, jitter=True, palette="Set2", alpha=0.6)

# Added a title and labels
plt.title('Price Distribution Across Different Neighborhoods', fontsize=16)
plt.xlabel('Neighborhood Group', fontsize=12)
plt.ylabel('Price (USD)', fontsize=12)

plt.show()
# Out:
# <ipython-input-68-1da36a78ca52>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='neighbourhood_group', y='price', data=df, jitter=True, palette="Set2", alpha=0.6)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Strip Plot: This chart shows individual data points (prices) for each neighborhood group. It uses jitter to prevent overlapping points, which provides a clear view of the distribution of prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The strip plot reveals that Manhattan has a wide range of prices, with many listings priced significantly higher than those in other neighborhoods, indicating it is a premium market. Brooklyn also shows a broad price range but with a larger concentration of more affordable listings. Staten Island and Queens have lower price ranges, with fewer high-priced listings, suggesting these areas are more affordable overall, with fewer outliers in the pricing distribution

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the strip plot can drive positive business impact by helping hosts and property managers tailor their pricing strategies. For example, Manhattan’s premium pricing allows hosts to capitalize on high demand and charge higher rates, while Brooklyn's mix of affordable and premium listings offers opportunities for varied pricing strategies targeting different customer segments. Staten Island and Queens could attract budget-conscious guests by offering more affordable listings, which could boost occupancy rates.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(12, 7))

# Created a count plot to visualize the distribution of room types across neighborhood groups
sns.countplot(x='neighbourhood_group', hue='room_type', data=df, palette="Set2")

# Added a title and labels
plt.title('Distribution of Room Types Across Neighborhood Groups', fontsize=16)
plt.xlabel('Neighborhood Group', fontsize=12)
plt.ylabel('Number of Listings', fontsize=12)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count Plot: This chart visualizes the number of listings across different room types, helping to identify which room types are more common in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This visualization  helps us understand the distribution of room types within the dataset and identify trends in the availability of different room categories in each and every cities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights from the count plot can help create a positive business impact by revealing the popularity of different room types. If a business observes that Private rooms or Entire homes/apartments have a high number of listings, they can consider increasing their inventory in those categories to meet demand. Additionally, businesses can optimize their marketing and pricing strategies based on which room types are more common and in demand.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(12, 7))

# Created a pivot table to visualize the relationship between price and neighborhood group
price_neighborhood = df.pivot_table(values='price', columns='neighbourhood_group', aggfunc='mean')

# Created a heatmap to show the relationship
sns.heatmap(price_neighborhood, annot=True, cmap="YlGnBu", linewidths=1, fmt=".2f")

# Added a title and labels
plt.title('Average Price Across Neighborhood Groups', fontsize=16)
plt.xlabel('Neighborhood Group', fontsize=12)
plt.ylabel('Average Price (USD)', fontsize=12)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart visualizes the average price for each neighborhood group using a heatmap. The color intensity represents the price range, with darker colors indicating higher prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This visualization helps us quickly compare the average price across various neighborhood groups, making it easy to spot high-price areas (like Manhattan) and more affordable ones like Queens and Bronx.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights from the heatmap can create a positive business impact by helping businesses tailor their pricing and marketing strategies to specific neighborhoods. For instance, if the heatmap shows that neighborhoods like Manhattan or Brooklyn have higher average prices, businesses can focus on offering premium services or adjust pricing to reflect the area's demand. In contrast, neighborhoods with lower average prices can be marketed to budget-conscious travelers, potentially increasing occupancy rates.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(12, 6))

# Created a histogram to visualize the distribution of the number of reviews
sns.histplot(df['number_of_reviews'], bins=30, kde=True, color='blue', edgecolor='black')

# Added a title and labels
plt.title('Distribution of Number of Reviews', fontsize=16)
plt.xlabel('Number of Reviews', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart visualizes the distribution of the number of reviews across all listings. The bins represent different ranges of review counts, and the KDE (Kernel Density Estimate) helps visualize the data distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This visualization allows us to understand how reviews are distributed across the listings and see whether most properties have a small or large number of reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights from the histogram can help create a positive business impact by identifying listings with a high number of reviews, which may indicate popular or well-regarded properties. Businesses can leverage this data to promote highly-reviewed listings or identify areas for improvement in listings with fewer reviews. However, listings with very few reviews could indicate lower guest engagement or satisfaction, which may lead to negative growth if not addressed. For example, properties with few reviews may struggle to build trust with potential customers, leading to lower occupancy rates and reduced revenue.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(12, 8))

# Calculated the correlation matrix for numerical columns only
corr_matrix = df.select_dtypes(include=np.number).corr()

sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

plt.title('Correlation Matrix of Numerical Variables', fontsize=16)

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap of correlations is chosen because it provides a clear and comprehensive visualization of how numerical variables are interrelated. The color scale helps to quickly identify strong correlations (both positive and negative), while the numerical values give exact correlation coefficients. This type of chart is helpful for identifying which variables might influence others, and thus help in understanding how different factors contribute to the performance of Airbnb listings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Yes, the insights from the heatmap will help optimize pricing, guest engagement, and occupancy strategies:
# Optimizing price and reviews: Understanding how price and reviews correlate can help businesses focus on improving guest experience for higher-priced listings, which could lead to increased reviews and, subsequently, higher demand.
# Availability optimization: If availability does not strongly correlate with price, businesses can consider making listings more available during peak periods without affecting the pricing structure, thus maximizing occupancy.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
numerical_cols = ['price', 'number_of_reviews', 'availability_365', 'calculated_host_listings_count', 'room_type']
# Included 'room_type' in the list of columns

# Setting up the size of the plot
sns.pairplot(df[numerical_cols], hue='room_type', palette='viridis') # Now 'room_type' is available

# Added a title
plt.suptitle('Pair Plot of Key Variables', fontsize=16, y=1.02)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is selected because it allows us to visualize the relationships between multiple variables in a dataset in one go. It gives insights into not only the distribution of each individual variable but also the pairwise correlations between them. Pair plots are useful in understanding how different variables, such as price, reviews, and availability, relate to each other, and whether there are any clustering patterns or outliers based on categories like room type. The color coding by room type provides additional insight into how these relationships vary across different property types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot reveals that entire home/apt listings generally have higher prices and accumulate more reviews compared to private rooms or shared rooms, indicating that larger, more expensive properties tend to attract more guests and feedback. Additionally, private rooms and shared rooms are typically priced lower, with some shared rooms showing higher availability, suggesting they may be more accessible or budget-friendly options. This clustering helps identify how different room types impact pricing, reviews, and availability, offering insights into how businesses can target different customer segments based on property type.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve the business objective of maximizing revenue and improving performance on Airbnb, I suggest the following strategies:
#
# Optimize Pricing Based on Room Type:
#
# Entire home/apartment listings tend to be priced higher and receive more reviews. To maximize bookings, focus on enhancing the guest experience for these listings, potentially offering premium amenities, and ensuring that these properties are priced competitively.
# For private rooms and shared rooms, adjust prices to reflect demand and market conditions, ensuring they are attractive to budget-conscious travelers while maintaining a healthy profit margin.
# Increase Guest Engagement and Reviews:
#
# Since reviews strongly correlate with higher prices and more visibility, encourage guests to leave reviews by offering incentives like discounts or perks for future stays. This can be especially important for private rooms and shared rooms, which may have fewer reviews.
# Focus on improving guest experience (e.g., cleanliness, communication, amenities) to boost reviews, which will, in turn, attract more guests and improve rankings in Airbnb search results.
# Target the Right Availability Strategy:
#
# High availability properties tend to be booked less frequently, particularly for higher-priced listings. For properties with higher availability, ensure they are marketed effectively, and consider adjusting the pricing for low-demand periods.
# For budget-friendly rooms (like shared rooms), ensure they have a competitive edge in terms of availability, location, and guest reviews to drive higher occupancy.
# Leverage Room Type Insights for Marketing:
#
# Use the insights about room types to target specific customer segments. For example, entire homes could be marketed to families or larger groups, while private rooms and shared rooms can appeal to solo travelers or budget-conscious guests.
# Highlight key features that set your listings apart, such as unique amenities or proximity to local attractions, to attract more guests based on the room type.
# By implementing these strategies, the business can maximize occupancy rates, increase customer satisfaction, and optimize pricing, which should ultimately lead to a higher revenue and a stronger competitive position in the Airbnb market.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, this exploratory data analysis of the Airbnb dataset has provided valuable insights into key factors influencing listings' success, such as price, reviews, availability, and room type. We observed clear patterns showing that entire homes/apartments tend to have higher prices and reviews, while shared rooms and private rooms appeal more to budget-conscious travelers with higher availability.
#
# By leveraging these insights, businesses can optimize their pricing strategies, improve guest satisfaction to encourage more reviews, and tailor marketing efforts to target the right customer segments based on room type. Additionally, focusing on optimizing availability and offering personalized guest experiences will help enhance bookings, leading to greater revenue generation.
#
# The strategies derived from this analysis are designed to align with the business objective of improving performance on Airbnb, ultimately contributing to a positive business impact through better pricing decisions, increased customer engagement, and improved listing visibility.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
